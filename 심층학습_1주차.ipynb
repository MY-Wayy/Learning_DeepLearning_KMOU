# %% [markdown]
# <a href="https://colab.research.google.com/github/MY-Wayy/Learning_DeepLearning_KMOU/blob/main/%EC%8B%AC%EC%B8%B5%ED%95%99%EC%8A%B5_1%EC%A3%BC%EC%B0%A8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello!")

# %% [markdown]
# ## 저자 깃허브 ch2 주피터노트북
# `https://colab.research.google.com/github/taehojo/deeplearning_4th/blob/master/colab/ch02-colab.ipynb` <br>
# <br>
# <br>
#
# ---

# %% [markdown]
# # 2장. 딥러닝 핵심 미리보기

# %% [markdown]
# ## 나의 첫 딥러닝: '10장 폐암 수술 환자의 생존율 예측' 코드 미리보기

# %% [markdown]
# ### 1. 환경 준비

# %%
from tensorflow.keras.models import Sequential  # 텐서플로의 케라스 API에서 필요한 함수들을 불러옵니다.
from tensorflow.keras.layers import Dense       # 데이터를 다루는 데 필요한 라이브러리를 불러옵니다.
import numpy as np

# %% [markdown]
# ### 2. 데이터 준비

# %%
# !git clone https://github.com/taehojo/data.git   # 깃허브에 준비된 데이터를 가져옵니다.

Data_set = np.loadtxt("./data/ThoraricSurgery3.csv", delimiter=",")  # 수술 환자 데이터를 불러옵니다.
X = Data_set[:,0:16]                                                 # 환자의 진찰 기록을 X로 지정합니다.
y = Data_set[:,16]                                                   # 수술 후 사망/생존 여부를 y로 지정합니다.

# %% [markdown]
# ### 3. 구조 결정

# %%
model = Sequential()                                                  # 딥러닝 모델의 구조를 결정합니다.
model.add(Dense(30, input_dim=16, activation='relu'))
model.add(Dense(1, activation='sigmoid'))

# %% [markdown]
# ### 4. 모델 실행

# %%
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])  # 딥러닝 모델을 실행합니다.
history=model.fit(X, y, epochs=5, batch_size=16)
# Out:
# Epoch 1/5
# 30/30 [==============================] - 1s 2ms/step - loss: 1.5790 - accuracy: 0.4957
# Epoch 2/5
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4954 - accuracy: 0.8511
# Epoch 3/5
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4470 - accuracy: 0.8511
# Epoch 4/5
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4369 - accuracy: 0.8511
# Epoch 5/5
# 30/30 [==============================] - 0s 2ms/step - loss: 0.4368 - accuracy: 0.8511
